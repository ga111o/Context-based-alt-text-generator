# %%
from langchain.chat_models import ChatOllama
from langchain.callbacks import StreamingStdOutCallbackHandler
from langchain.document_loaders import UnstructuredFileLoader
from PIL import Image

# %%
model = ChatOllama(
    model = "llama3:8b",
    temperature=0.1,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()]
)

# %%
img = Image.open('0.png')

img_rgb = img.convert('RGB')

img_rgb.save('output.pdf')

# %%
loader = UnstructuredFileLoader("output.pdf")
# loader = UnstructuredFileLoader("test.txt")

# loader = UnstructuredImageLoader(
#     "./0.jpg", mode="elements", strategy="fast"
#     )

# docs = loader.load()

loader.load()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/pdf2image/pdf2image.py:568, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     567     env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 568 proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     570 try:
#
# File /usr/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File /usr/lib/python3.11/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pdfinfo'
#
# During handling of the above exception, another exception occurred:
#
# PDFInfoNotInstalledError                  Traceback (most recent call last)
# Cell In[11], line 10
#       1 loader = UnstructuredFileLoader("output.pdf")
#       2 # loader = UnstructuredFileLoader("test.txt")
#       3
#       4 # loader = UnstructuredImageLoader(
#    (...)
#       7
#       8 # docs = loader.load()
# ---> 10 loader.load()
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/langchain/document_loaders/unstructured.py:86, in UnstructuredBaseLoader.load(self)
#      84 def load(self) -> List[Document]:
#      85     """Load file."""
# ---> 86     elements = self._get_elements()
#      87     self._post_process_elements(elements)
#      88     if self.mode == "elements":
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/langchain/document_loaders/unstructured.py:172, in UnstructuredFileLoader._get_elements(self)
#     169 def _get_elements(self) -> List:
#     170     from unstructured.partition.auto import partition
# --> 172     return partition(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/partition/auto.py:316, in partition(filename, content_type, file, file_filename, url, include_page_breaks, strategy, encoding, paragraph_grouper, headers, skip_infer_table_types, ssl_verify, ocr_languages, languages, pdf_infer_table_structure, xml_keep_tags, data_source_metadata, metadata_filename, **kwargs)
#     314 elif filetype == FileType.PDF:
#     315     _partition_pdf = _get_partition_with_extras("pdf")
# --> 316     elements = _partition_pdf(
#     317         filename=filename,  # type: ignore
#     318         file=file,  # type: ignore
#     319         url=None,
#     320         include_page_breaks=include_page_breaks,
#     321         infer_table_structure=infer_table_structure,
#     322         strategy=strategy,
#     323         languages=languages,
#     324         **kwargs,
#     325     )
#     326 elif (filetype == FileType.PNG) or (filetype == FileType.JPG) or (filetype == FileType.TIFF):
#     327     elements = partition_image(
#     328         filename=filename,  # type: ignore
#     329         file=file,  # type: ignore
#    (...)
#     335         **kwargs,
#     336     )
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/documents/elements.py:244, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     242 @functools.wraps(func)
#     243 def wrapper(*args, **kwargs):
# --> 244     elements = func(*args, **kwargs)
#     245     sig = inspect.signature(func)
#     246     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/file_utils/filetype.py:541, in add_metadata_with_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     539 @wraps(func)
#     540 def wrapper(*args, **kwargs):
# --> 541     elements = func(*args, **kwargs)
#     542     sig = inspect.signature(func)
#     543     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/chunking/title.py:197, in add_chunking_strategy.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     195 @wraps(func)
#     196 def wrapper(*args, **kwargs):
# --> 197     elements = func(*args, **kwargs)
#     198     sig = inspect.signature(func)
#     199     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/partition/pdf.py:130, in partition_pdf(filename, file, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, max_partition, min_partition, include_metadata, metadata_filename, metadata_last_modified, chunking_strategy, **kwargs)
#     124         languages = convert_old_ocr_languages_to_languages(ocr_languages)
#     125         logger.warning(
#     126             "The ocr_languages kwarg will be deprecated in a future version of unstructured. "
#     127             "Please use languages instead.",
#     128         )
# --> 130 return partition_pdf_or_image(
#     131     filename=filename,
#     132     file=file,
#     133     include_page_breaks=include_page_breaks,
#     134     strategy=strategy,
#     135     infer_table_structure=infer_table_structure,
#     136     languages=languages,
#     137     max_partition=max_partition,
#     138     min_partition=min_partition,
#     139     metadata_last_modified=metadata_last_modified,
#     140     **kwargs,
#     141 )
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/partition/pdf.py:277, in partition_pdf_or_image(filename, file, is_image, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, max_partition, min_partition, metadata_last_modified, **kwargs)
#     274 elif strategy == "ocr_only":
#     275     # NOTE(robinson): Catches file conversion warnings when running with PDFs
#     276     with warnings.catch_warnings():
# --> 277         return _partition_pdf_or_image_with_ocr(
#     278             filename=filename,
#     279             file=file,
#     280             include_page_breaks=include_page_breaks,
#     281             languages=languages,
#     282             is_image=is_image,
#     283             max_partition=max_partition,
#     284             min_partition=min_partition,
#     285             metadata_last_modified=metadata_last_modified or last_modification_date,
#     286         )
#     288 return layout_elements
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/utils.py:156, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     147 if len(missing_deps) > 0:
#     148     raise ImportError(
#     149         f"Following dependencies are missing: {', '.join(missing_deps)}. "
#     150         + (
#    (...)
#     154         ),
#     155     )
# --> 156 return func(*args, **kwargs)
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/partition/pdf.py:709, in _partition_pdf_or_image_with_ocr(filename, file, include_page_breaks, languages, is_image, max_partition, min_partition, metadata_last_modified)
#     707 elements = []
#     708 page_number = 0
# --> 709 for image in convert_pdf_to_images(filename, file):
#     710     page_number += 1
#     711     metadata = ElementMetadata(
#     712         filename=filename,
#     713         page_number=page_number,
#     714         last_modified=metadata_last_modified,
#     715     )
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/partition/pdf.py:553, in convert_pdf_to_images(filename, file, chunk_size)
#     551 else:
#     552     f_bytes = None
# --> 553     info = pdf2image.pdfinfo_from_path(filename)
#     555 total_pages = info["Pages"]
#     556 for start_page in range(1, total_pages + 1, chunk_size):
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/pdf2image/pdf2image.py:594, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     591     return d
#     593 except OSError:
# --> 594     raise PDFInfoNotInstalledError(
#     595         "Unable to get page count. Is poppler installed and in PATH?"
#     596     )
#     597 except ValueError:
#     598     raise PDFPageCountError(
#     599         f"Unable to get page count.\n{err.decode('utf8', 'ignore')}"
#     600     )
#
# PDFInfoNotInstalledError: Unable to get page count. Is poppler installed and in PATH?
