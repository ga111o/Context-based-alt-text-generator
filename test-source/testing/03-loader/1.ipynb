# %%
from langchain.chat_models import ChatOllama
from langchain.callbacks import StreamingStdOutCallbackHandler
from langchain.document_loaders import UnstructuredFileLoader

# %%
model = ChatOllama(
    model = "llama3:8b",
    temperature=0.1,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()]
)

# %%
loader = UnstructuredFileLoader("0.png")
# loader = UnstructuredFileLoader("test.txt")

# loader = UnstructuredImageLoader(
#     "./0.jpg", mode="elements", strategy="fast"
#     )

# docs = loader.load()

loader.load()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/pytesseract/pytesseract.py:388, in get_tesseract_version()
#     387 try:
# --> 388     output = subprocess.check_output(
#     389         [tesseract_cmd, '--version'],
#     390         stderr=subprocess.STDOUT,
#     391         env=environ,
#     392         stdin=subprocess.DEVNULL,
#     393     )
#     394 except OSError:
#
# File /usr/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File /usr/lib/python3.11/subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# File /usr/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File /usr/lib/python3.11/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tesseract'
#
# During handling of the above exception, another exception occurred:
#
# TesseractNotFoundError                    Traceback (most recent call last)
# Cell In[7], line 10
#       1 loader = UnstructuredFileLoader("0.png")
#       2 # loader = UnstructuredFileLoader("test.txt")
#       3
#       4 # loader = UnstructuredImageLoader(
#    (...)
#       7
#       8 # docs = loader.load()
# ---> 10 loader.load()
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/langchain/document_loaders/unstructured.py:86, in UnstructuredBaseLoader.load(self)
#      84 def load(self) -> List[Document]:
#      85     """Load file."""
# ---> 86     elements = self._get_elements()
#      87     self._post_process_elements(elements)
#      88     if self.mode == "elements":
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/langchain/document_loaders/unstructured.py:172, in UnstructuredFileLoader._get_elements(self)
#     169 def _get_elements(self) -> List:
#     170     from unstructured.partition.auto import partition
# --> 172     return partition(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/partition/auto.py:327, in partition(filename, content_type, file, file_filename, url, include_page_breaks, strategy, encoding, paragraph_grouper, headers, skip_infer_table_types, ssl_verify, ocr_languages, languages, pdf_infer_table_structure, xml_keep_tags, data_source_metadata, metadata_filename, **kwargs)
#     316     elements = _partition_pdf(
#     317         filename=filename,  # type: ignore
#     318         file=file,  # type: ignore
#    (...)
#     324         **kwargs,
#     325     )
#     326 elif (filetype == FileType.PNG) or (filetype == FileType.JPG) or (filetype == FileType.TIFF):
# --> 327     elements = partition_image(
#     328         filename=filename,  # type: ignore
#     329         file=file,  # type: ignore
#     330         url=None,
#     331         include_page_breaks=include_page_breaks,
#     332         infer_table_structure=infer_table_structure,
#     333         strategy=strategy,
#     334         languages=languages,
#     335         **kwargs,
#     336     )
#     337 elif filetype == FileType.TXT:
#     338     elements = partition_text(
#     339         filename=filename,
#     340         file=file,
#    (...)
#     343         **kwargs,
#     344     )
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/documents/elements.py:244, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     242 @functools.wraps(func)
#     243 def wrapper(*args, **kwargs):
# --> 244     elements = func(*args, **kwargs)
#     245     sig = inspect.signature(func)
#     246     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/chunking/title.py:197, in add_chunking_strategy.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     195 @wraps(func)
#     196 def wrapper(*args, **kwargs):
# --> 197     elements = func(*args, **kwargs)
#     198     sig = inspect.signature(func)
#     199     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/partition/image.py:75, in partition_image(filename, file, include_page_breaks, infer_table_structure, ocr_languages, languages, strategy, metadata_last_modified, chunking_strategy, **kwargs)
#      69         languages = convert_old_ocr_languages_to_languages(ocr_languages)
#      70         logger.warning(
#      71             "The ocr_languages kwarg will be deprecated in a future version of unstructured. "
#      72             "Please use languages instead.",
#      73         )
# ---> 75 return partition_pdf_or_image(
#      76     filename=filename,
#      77     file=file,
#      78     is_image=True,
#      79     include_page_breaks=include_page_breaks,
#      80     infer_table_structure=infer_table_structure,
#      81     languages=languages,
#      82     strategy=strategy,
#      83     metadata_last_modified=metadata_last_modified,
#      84     **kwargs,
#      85 )
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/partition/pdf.py:251, in partition_pdf_or_image(filename, file, is_image, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, max_partition, min_partition, metadata_last_modified, **kwargs)
#     249 with warnings.catch_warnings():
#     250     warnings.simplefilter("ignore")
# --> 251     _layout_elements = _partition_pdf_or_image_local(
#     252         filename=filename,
#     253         file=spooled_to_bytes_io_if_needed(file),
#     254         is_image=is_image,
#     255         infer_table_structure=infer_table_structure,
#     256         include_page_breaks=include_page_breaks,
#     257         languages=languages,
#     258         ocr_mode="entire_page",
#     259         metadata_last_modified=metadata_last_modified or last_modification_date,
#     260         **kwargs,
#     261     )
#     262     layout_elements = []
#     263     for el in _layout_elements:
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/utils.py:156, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     147 if len(missing_deps) > 0:
#     148     raise ImportError(
#     149         f"Following dependencies are missing: {', '.join(missing_deps)}. "
#     150         + (
#    (...)
#     154         ),
#     155     )
# --> 156 return func(*args, **kwargs)
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured/partition/pdf.py:324, in _partition_pdf_or_image_local(filename, file, is_image, infer_table_structure, include_page_breaks, languages, ocr_mode, model_name, metadata_last_modified, **kwargs)
#     322     if pdf_image_dpi:
#     323         process_file_with_model_kwargs["pdf_image_dpi"] = pdf_image_dpi
# --> 324     layout = process_file_with_model(
#     325         filename,
#     326         **process_file_with_model_kwargs,
#     327     )
#     328 else:
#     329     layout = process_data_with_model(
#     330         file,
#     331         is_image=is_image,
#    (...)
#     335         model_name=model_name,
#     336     )
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured_inference/inference/layout.py:600, in process_file_with_model(filename, model_name, is_image, ocr_strategy, ocr_languages, ocr_mode, fixed_layouts, extract_tables, pdf_image_dpi, **kwargs)
#     597 else:
#     598     raise ValueError(f"Unsupported model type: {type(model)}")
#     599 layout = (
# --> 600     DocumentLayout.from_image_file(
#     601         filename,
#     602         detection_model=detection_model,
#     603         element_extraction_model=element_extraction_model,
#     604         ocr_strategy=ocr_strategy,
#     605         ocr_languages=ocr_languages,
#     606         ocr_mode=ocr_mode,
#     607         extract_tables=extract_tables,
#     608         **kwargs,
#     609     )
#     610     if is_image
#     611     else DocumentLayout.from_file(
#     612         filename,
#     613         detection_model=detection_model,
#     614         element_extraction_model=element_extraction_model,
#     615         ocr_strategy=ocr_strategy,
#     616         ocr_languages=ocr_languages,
#     617         ocr_mode=ocr_mode,
#     618         fixed_layouts=fixed_layouts,
#     619         extract_tables=extract_tables,
#     620         pdf_image_dpi=pdf_image_dpi,
#     621         **kwargs,
#     622     )
#     623 )
#     624 return layout
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured_inference/inference/layout.py:167, in DocumentLayout.from_image_file(cls, filename, detection_model, element_extraction_model, ocr_strategy, ocr_languages, ocr_mode, fixed_layout, extract_tables, **kwargs)
#     165 pages = []
#     166 for i, image in enumerate(images):
# --> 167     page = PageLayout.from_image(
#     168         image,
#     169         image_path=filename,
#     170         number=i,
#     171         detection_model=detection_model,
#     172         element_extraction_model=element_extraction_model,
#     173         layout=None,
#     174         ocr_strategy=ocr_strategy,
#     175         ocr_languages=ocr_languages,
#     176         ocr_mode=ocr_mode,
#     177         fixed_layout=fixed_layout,
#     178         extract_tables=extract_tables,
#     179         **kwargs,
#     180     )
#     181     pages.append(page)
#     182 return cls.from_pages(pages)
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured_inference/inference/layout.py:513, in PageLayout.from_image(cls, image, image_path, document_filename, number, detection_model, element_extraction_model, layout, ocr_strategy, ocr_languages, ocr_mode, extract_tables, fixed_layout, supplement_with_ocr_elements, extract_images_in_pdf, image_output_dir_path, analysis)
#     511     return page
#     512 if fixed_layout is None:
# --> 513     page.get_elements_with_detection_model()
#     514 else:
#     515     page.elements = page.get_elements_from_layout(fixed_layout)
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/unstructured_inference/inference/layout.py:290, in PageLayout.get_elements_with_detection_model(self, inplace)
#     288 logger.info("Processing entrie page OCR with tesseract...")
#     289 try:
# --> 290     ocr_data = pytesseract.image_to_data(
#     291         self.image,
#     292         lang=self.ocr_languages,
#     293         output_type=Output.DICT,
#     294     )
#     295     ocr_layout = parse_ocr_data_tesseract(ocr_data)
#     296 except pytesseract.pytesseract.TesseractError:
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/pytesseract/pytesseract.py:521, in image_to_data(image, lang, config, nice, output_type, timeout, pandas_config)
#     507 def image_to_data(
#     508     image,
#     509     lang=None,
#    (...)
#     514     pandas_config=None,
#     515 ):
#     516     """
#     517     Returns string containing box boundaries, confidences,
#     518     and other information. Requires Tesseract 3.05+
#     519     """
# --> 521     if get_tesseract_version() < TESSERACT_MIN_VERSION:
#     522         raise TSVNotSupported()
#     524     config = f'-c tessedit_create_tsv=1 {config.strip()}'
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/pytesseract/pytesseract.py:146, in run_once.<locals>.wrapper(*args, **kwargs)
#     143 @wraps(func)
#     144 def wrapper(*args, **kwargs):
#     145     if wrapper._result is wrapper:
# --> 146         wrapper._result = func(*args, **kwargs)
#     147     return wrapper._result
#
# File ~/document/MarkDown/kwu-idea-lab/projects/add-alt-using-llm/env/lib/python3.11/site-packages/pytesseract/pytesseract.py:395, in get_tesseract_version()
#     388     output = subprocess.check_output(
#     389         [tesseract_cmd, '--version'],
#     390         stderr=subprocess.STDOUT,
#     391         env=environ,
#     392         stdin=subprocess.DEVNULL,
#     393     )
#     394 except OSError:
# --> 395     raise TesseractNotFoundError()
#     397 raw_version = output.decode(DEFAULT_ENCODING)
#     398 str_version, *_ = raw_version.lstrip(string.printable[10:]).partition(' ')
#
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.
